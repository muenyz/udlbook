# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1=self.linear1(x)
    h2=h1+self.linear2(torch.relu(h1))
    h3=h2+self.linear3(torch.relu(h2))
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.741675, train error 63.28,  val loss 1.899931, percent error 66.10
# Epoch     1, train loss 1.210281, train error 46.33,  val loss 1.383659, percent error 52.10
# Epoch     2, train loss 0.994515, train error 37.38,  val loss 1.227802, percent error 45.40
# Epoch     3, train loss 0.933797, train error 35.65,  val loss 1.213721, percent error 45.90
# Epoch     4, train loss 0.816934, train error 30.40,  val loss 1.126570, percent error 42.80
# Epoch     5, train loss 0.787508, train error 29.62,  val loss 1.176081, percent error 43.50
# Epoch     6, train loss 0.733221, train error 27.00,  val loss 1.197741, percent error 42.80
# Epoch     7, train loss 0.594490, train error 22.45,  val loss 1.125367, percent error 39.90
# Epoch     8, train loss 0.573179, train error 21.53,  val loss 1.141835, percent error 37.40
# Epoch     9, train loss 0.605366, train error 22.97,  val loss 1.264479, percent error 40.00
# Epoch    10, train loss 0.434552, train error 16.68,  val loss 1.109077, percent error 37.50
# Epoch    11, train loss 0.453774, train error 16.60,  val loss 1.222741, percent error 35.60
# Epoch    12, train loss 0.433603, train error 15.97,  val loss 1.196867, percent error 37.80
# Epoch    13, train loss 0.406797, train error 15.72,  val loss 1.253870, percent error 37.20
# Epoch    14, train loss 0.329133, train error 12.10,  val loss 1.344958, percent error 36.20
# Epoch    15, train loss 0.351144, train error 12.68,  val loss 1.403077, percent error 37.50
# Epoch    16, train loss 0.384970, train error 13.20,  val loss 1.411292, percent error 34.60
# Epoch    17, train loss 0.408999, train error 14.32,  val loss 1.566033, percent error 40.20
# Epoch    18, train loss 0.333004, train error 11.82,  val loss 1.551592, percent error 36.90
# Epoch    19, train loss 0.290304, train error 10.00,  val loss 1.566939, percent error 34.40
# Epoch    20, train loss 0.076623, train error 1.93,  val loss 1.288322, percent error 31.00
# Epoch    21, train loss 0.037740, train error 0.40,  val loss 1.236041, percent error 30.00
# Epoch    22, train loss 0.023158, train error 0.12,  val loss 1.275203, percent error 30.30
# Epoch    23, train loss 0.015696, train error 0.03,  val loss 1.320400, percent error 30.60
# Epoch    24, train loss 0.012331, train error 0.00,  val loss 1.332247, percent error 30.50
# Epoch    25, train loss 0.010164, train error 0.00,  val loss 1.353425, percent error 29.80
# Epoch    26, train loss 0.008794, train error 0.00,  val loss 1.385329, percent error 29.90
# Epoch    27, train loss 0.007771, train error 0.00,  val loss 1.409404, percent error 30.40
# Epoch    28, train loss 0.007006, train error 0.00,  val loss 1.426201, percent error 30.50
# Epoch    29, train loss 0.006386, train error 0.00,  val loss 1.448167, percent error 30.00
# Epoch    30, train loss 0.005812, train error 0.00,  val loss 1.463393, percent error 29.90
# Epoch    31, train loss 0.005370, train error 0.00,  val loss 1.479303, percent error 30.50
# Epoch    32, train loss 0.004983, train error 0.00,  val loss 1.495577, percent error 29.90
# Epoch    33, train loss 0.004649, train error 0.00,  val loss 1.505534, percent error 30.50
# Epoch    34, train loss 0.004339, train error 0.00,  val loss 1.521736, percent error 30.10
# Epoch    35, train loss 0.004079, train error 0.00,  val loss 1.531675, percent error 30.20
# Epoch    36, train loss 0.003848, train error 0.00,  val loss 1.543867, percent error 30.20
# Epoch    37, train loss 0.003637, train error 0.00,  val loss 1.554920, percent error 30.20
# Epoch    38, train loss 0.003460, train error 0.00,  val loss 1.569773, percent error 29.90
# Epoch    39, train loss 0.003286, train error 0.00,  val loss 1.575726, percent error 30.10
# Epoch    40, train loss 0.003200, train error 0.00,  val loss 1.582555, percent error 30.00
# Epoch    41, train loss 0.003126, train error 0.00,  val loss 1.587302, percent error 30.20
# Epoch    42, train loss 0.003055, train error 0.00,  val loss 1.592465, percent error 30.00
# Epoch    43, train loss 0.002988, train error 0.00,  val loss 1.596492, percent error 30.10
# Epoch    44, train loss 0.002923, train error 0.00,  val loss 1.600546, percent error 30.10
# Epoch    45, train loss 0.002862, train error 0.00,  val loss 1.605937, percent error 30.00
# Epoch    46, train loss 0.002801, train error 0.00,  val loss 1.610541, percent error 30.10
# Epoch    47, train loss 0.002744, train error 0.00,  val loss 1.614020, percent error 30.10
# Epoch    48, train loss 0.002689, train error 0.00,  val loss 1.618796, percent error 30.00
# Epoch    49, train loss 0.002636, train error 0.00,  val loss 1.622544, percent error 30.10
# Epoch    50, train loss 0.002585, train error 0.00,  val loss 1.626683, percent error 30.00
# Epoch    51, train loss 0.002536, train error 0.00,  val loss 1.630413, percent error 30.00
# Epoch    52, train loss 0.002488, train error 0.00,  val loss 1.635098, percent error 30.30
# Epoch    53, train loss 0.002443, train error 0.00,  val loss 1.637929, percent error 30.00
# Epoch    54, train loss 0.002398, train error 0.00,  val loss 1.642515, percent error 30.20
# Epoch    55, train loss 0.002355, train error 0.00,  val loss 1.645824, percent error 30.20
# Epoch    56, train loss 0.002314, train error 0.00,  val loss 1.649137, percent error 30.10
# Epoch    57, train loss 0.002273, train error 0.00,  val loss 1.653596, percent error 30.30
# Epoch    58, train loss 0.002235, train error 0.00,  val loss 1.656722, percent error 30.00
# Epoch    59, train loss 0.002197, train error 0.00,  val loss 1.660321, percent error 30.20
# Epoch    60, train loss 0.002178, train error 0.00,  val loss 1.662554, percent error 30.20
# Epoch    61, train loss 0.002160, train error 0.00,  val loss 1.664405, percent error 30.30
# Epoch    62, train loss 0.002143, train error 0.00,  val loss 1.666097, percent error 30.20
# Epoch    63, train loss 0.002125, train error 0.00,  val loss 1.667800, percent error 30.30
# Epoch    64, train loss 0.002108, train error 0.00,  val loss 1.669522, percent error 30.20
# Epoch    65, train loss 0.002091, train error 0.00,  val loss 1.671210, percent error 30.20
# Epoch    66, train loss 0.002075, train error 0.00,  val loss 1.672355, percent error 30.30
# Epoch    67, train loss 0.002058, train error 0.00,  val loss 1.674538, percent error 30.30
# Epoch    68, train loss 0.002042, train error 0.00,  val loss 1.676059, percent error 30.30
# Epoch    69, train loss 0.002026, train error 0.00,  val loss 1.678048, percent error 30.20
# Epoch    70, train loss 0.002011, train error 0.00,  val loss 1.679894, percent error 30.30
# Epoch    71, train loss 0.001995, train error 0.00,  val loss 1.681075, percent error 30.20
# Epoch    72, train loss 0.001980, train error 0.00,  val loss 1.683061, percent error 30.20
# Epoch    73, train loss 0.001965, train error 0.00,  val loss 1.684677, percent error 30.20
# Epoch    74, train loss 0.001950, train error 0.00,  val loss 1.686013, percent error 30.20
# Epoch    75, train loss 0.001936, train error 0.00,  val loss 1.687461, percent error 30.20
# Epoch    76, train loss 0.001922, train error 0.00,  val loss 1.689540, percent error 30.20
# Epoch    77, train loss 0.001907, train error 0.00,  val loss 1.690223, percent error 30.20
# Epoch    78, train loss 0.001893, train error 0.00,  val loss 1.692141, percent error 30.20
# Epoch    79, train loss 0.001880, train error 0.00,  val loss 1.693753, percent error 30.20
# Epoch    80, train loss 0.001873, train error 0.00,  val loss 1.694547, percent error 30.20
# Epoch    81, train loss 0.001866, train error 0.00,  val loss 1.695467, percent error 30.20
# Epoch    82, train loss 0.001859, train error 0.00,  val loss 1.696136, percent error 30.20
# Epoch    83, train loss 0.001852, train error 0.00,  val loss 1.696673, percent error 30.20
# Epoch    84, train loss 0.001846, train error 0.00,  val loss 1.697514, percent error 30.20
# Epoch    85, train loss 0.001839, train error 0.00,  val loss 1.698395, percent error 30.20
# Epoch    86, train loss 0.001833, train error 0.00,  val loss 1.699291, percent error 30.20
# Epoch    87, train loss 0.001826, train error 0.00,  val loss 1.699445, percent error 30.20
# Epoch    88, train loss 0.001820, train error 0.00,  val loss 1.700620, percent error 30.20
# Epoch    89, train loss 0.001813, train error 0.00,  val loss 1.701320, percent error 30.20
# Epoch    90, train loss 0.001807, train error 0.00,  val loss 1.701854, percent error 30.20
# Epoch    91, train loss 0.001801, train error 0.00,  val loss 1.702824, percent error 30.20
# Epoch    92, train loss 0.001794, train error 0.00,  val loss 1.703706, percent error 30.20
# Epoch    93, train loss 0.001788, train error 0.00,  val loss 1.704160, percent error 30.20
# Epoch    94, train loss 0.001782, train error 0.00,  val loss 1.705090, percent error 30.20
# Epoch    95, train loss 0.001776, train error 0.00,  val loss 1.705818, percent error 30.10
# Epoch    96, train loss 0.001770, train error 0.00,  val loss 1.706351, percent error 30.20
# Epoch    97, train loss 0.001764, train error 0.00,  val loss 1.707284, percent error 30.20
# Epoch    98, train loss 0.001758, train error 0.00,  val loss 1.708006, percent error 30.20
# Epoch    99, train loss 0.001752, train error 0.00,  val loss 1.708671, percent error 30.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
