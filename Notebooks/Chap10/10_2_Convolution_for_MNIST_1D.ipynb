# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Conv1d(in_channels=1,out_channels=15,kernel_size=3,stride=2,padding="valid"),
nn.ReLU(),
nn.Conv1d(in_channels=15,out_channels=15,kernel_size=3,stride=2,padding="valid"),
nn.ReLU(),
nn.Conv1d(in_channels=15,out_channels=15,kernel_size=3,stride=2,padding="valid"),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60,10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.799428, train error 73.95,  val loss 1.813555, percent error 75.70
# Epoch     1, train loss 1.535561, train error 62.28,  val loss 1.572975, percent error 65.40
# Epoch     2, train loss 1.321843, train error 53.45,  val loss 1.350500, percent error 56.70
# Epoch     3, train loss 1.288044, train error 52.30,  val loss 1.316192, percent error 53.80
# Epoch     4, train loss 1.214066, train error 50.62,  val loss 1.242561, percent error 52.70
# Epoch     5, train loss 1.165953, train error 47.25,  val loss 1.187480, percent error 48.80
# Epoch     6, train loss 1.014071, train error 40.17,  val loss 1.046925, percent error 44.50
# Epoch     7, train loss 0.917162, train error 37.47,  val loss 0.975006, percent error 39.60
# Epoch     8, train loss 0.829418, train error 34.00,  val loss 0.873752, percent error 38.20
# Epoch     9, train loss 0.802607, train error 32.50,  val loss 0.857886, percent error 36.20
# Epoch    10, train loss 0.727359, train error 27.90,  val loss 0.788133, percent error 30.50
# Epoch    11, train loss 0.640433, train error 25.05,  val loss 0.692822, percent error 26.80
# Epoch    12, train loss 0.572880, train error 21.50,  val loss 0.645510, percent error 25.20
# Epoch    13, train loss 0.499471, train error 18.60,  val loss 0.593358, percent error 22.10
# Epoch    14, train loss 0.437479, train error 15.55,  val loss 0.541157, percent error 20.90
# Epoch    15, train loss 0.450309, train error 16.82,  val loss 0.535250, percent error 21.90
# Epoch    16, train loss 0.362016, train error 13.95,  val loss 0.506574, percent error 19.50
# Epoch    17, train loss 0.332483, train error 12.57,  val loss 0.484010, percent error 17.20
# Epoch    18, train loss 0.306776, train error 10.50,  val loss 0.442984, percent error 15.40
# Epoch    19, train loss 0.322410, train error 11.30,  val loss 0.486247, percent error 16.10
# Epoch    20, train loss 0.218146, train error 7.35,  val loss 0.375058, percent error 12.50
# Epoch    21, train loss 0.269990, train error 10.18,  val loss 0.455466, percent error 15.70
# Epoch    22, train loss 0.194150, train error 6.35,  val loss 0.370068, percent error 11.70
# Epoch    23, train loss 0.178755, train error 5.88,  val loss 0.353909, percent error 11.70
# Epoch    24, train loss 0.165052, train error 5.30,  val loss 0.377404, percent error 11.70
# Epoch    25, train loss 0.166422, train error 5.45,  val loss 0.376075, percent error 11.80
# Epoch    26, train loss 0.155364, train error 5.10,  val loss 0.364971, percent error 10.40
# Epoch    27, train loss 0.160241, train error 5.47,  val loss 0.377809, percent error 11.40
# Epoch    28, train loss 0.149091, train error 5.10,  val loss 0.368682, percent error 10.80
# Epoch    29, train loss 0.132096, train error 4.47,  val loss 0.363155, percent error 10.90
# Epoch    30, train loss 0.122376, train error 3.75,  val loss 0.353669, percent error 10.20
# Epoch    31, train loss 0.129851, train error 4.00,  val loss 0.376627, percent error 11.20
# Epoch    32, train loss 0.129689, train error 4.28,  val loss 0.349399, percent error 10.50
# Epoch    33, train loss 0.172277, train error 5.93,  val loss 0.427735, percent error 12.80
# Epoch    34, train loss 0.127737, train error 4.32,  val loss 0.349368, percent error 11.00
# Epoch    35, train loss 0.100134, train error 2.90,  val loss 0.355511, percent error 10.70
# Epoch    36, train loss 0.112637, train error 3.72,  val loss 0.370434, percent error 10.00
# Epoch    37, train loss 0.095774, train error 2.78,  val loss 0.347398, percent error 9.50
# Epoch    38, train loss 0.088028, train error 2.35,  val loss 0.357403, percent error 9.80
# Epoch    39, train loss 0.085604, train error 2.57,  val loss 0.344133, percent error 9.80
# Epoch    40, train loss 0.078566, train error 2.32,  val loss 0.346173, percent error 9.30
# Epoch    41, train loss 0.077101, train error 2.12,  val loss 0.347797, percent error 9.00
# Epoch    42, train loss 0.075097, train error 1.97,  val loss 0.353007, percent error 9.10
# Epoch    43, train loss 0.069391, train error 1.78,  val loss 0.342508, percent error 8.90
# Epoch    44, train loss 0.076442, train error 2.22,  val loss 0.360742, percent error 9.00
# Epoch    45, train loss 0.064342, train error 1.65,  val loss 0.353844, percent error 8.70
# Epoch    46, train loss 0.068416, train error 1.78,  val loss 0.349556, percent error 9.10
# Epoch    47, train loss 0.062864, train error 1.47,  val loss 0.350634, percent error 8.70
# Epoch    48, train loss 0.062883, train error 1.55,  val loss 0.358637, percent error 8.20
# Epoch    49, train loss 0.060983, train error 1.40,  val loss 0.353641, percent error 8.40
# Epoch    50, train loss 0.057637, train error 1.25,  val loss 0.353436, percent error 8.30
# Epoch    51, train loss 0.059029, train error 1.38,  val loss 0.361489, percent error 8.60
# Epoch    52, train loss 0.055174, train error 1.28,  val loss 0.355945, percent error 8.40
# Epoch    53, train loss 0.055174, train error 1.22,  val loss 0.368901, percent error 8.90
# Epoch    54, train loss 0.056869, train error 1.22,  val loss 0.364810, percent error 8.90
# Epoch    55, train loss 0.053525, train error 1.18,  val loss 0.373585, percent error 9.10
# Epoch    56, train loss 0.053212, train error 1.12,  val loss 0.363886, percent error 9.00
# Epoch    57, train loss 0.063897, train error 1.82,  val loss 0.394683, percent error 9.60
# Epoch    58, train loss 0.058977, train error 1.60,  val loss 0.373345, percent error 8.50
# Epoch    59, train loss 0.050912, train error 1.03,  val loss 0.372372, percent error 8.30
# Epoch    60, train loss 0.047488, train error 0.88,  val loss 0.364461, percent error 8.60
# Epoch    61, train loss 0.047030, train error 0.88,  val loss 0.365148, percent error 8.40
# Epoch    62, train loss 0.046441, train error 0.85,  val loss 0.368607, percent error 8.30
# Epoch    63, train loss 0.048373, train error 1.10,  val loss 0.374940, percent error 9.20
# Epoch    64, train loss 0.046024, train error 0.93,  val loss 0.370352, percent error 8.30
# Epoch    65, train loss 0.044251, train error 0.78,  val loss 0.372667, percent error 8.40
# Epoch    66, train loss 0.044701, train error 0.90,  val loss 0.378035, percent error 8.30
# Epoch    67, train loss 0.043787, train error 0.82,  val loss 0.373926, percent error 8.50
# Epoch    68, train loss 0.045221, train error 0.88,  val loss 0.383360, percent error 8.80
# Epoch    69, train loss 0.042534, train error 0.75,  val loss 0.379686, percent error 8.70
# Epoch    70, train loss 0.042899, train error 0.85,  val loss 0.378701, percent error 8.50
# Epoch    71, train loss 0.042481, train error 0.70,  val loss 0.380499, percent error 8.80
# Epoch    72, train loss 0.043173, train error 0.80,  val loss 0.382093, percent error 8.40
# Epoch    73, train loss 0.042986, train error 0.85,  val loss 0.382525, percent error 8.70
# Epoch    74, train loss 0.042168, train error 0.78,  val loss 0.385157, percent error 8.80
# Epoch    75, train loss 0.041078, train error 0.82,  val loss 0.385638, percent error 8.60
# Epoch    76, train loss 0.041279, train error 0.70,  val loss 0.386807, percent error 8.60
# Epoch    77, train loss 0.040528, train error 0.72,  val loss 0.382626, percent error 8.10
# Epoch    78, train loss 0.040096, train error 0.70,  val loss 0.376622, percent error 8.50
# Epoch    79, train loss 0.038927, train error 0.65,  val loss 0.386796, percent error 8.70
# Epoch    80, train loss 0.038449, train error 0.68,  val loss 0.386627, percent error 8.70
# Epoch    81, train loss 0.038682, train error 0.65,  val loss 0.385343, percent error 8.50
# Epoch    82, train loss 0.039239, train error 0.72,  val loss 0.388892, percent error 8.60
# Epoch    83, train loss 0.037790, train error 0.68,  val loss 0.385156, percent error 8.50
# Epoch    84, train loss 0.037594, train error 0.62,  val loss 0.387265, percent error 8.40
# Epoch    85, train loss 0.037915, train error 0.60,  val loss 0.388903, percent error 8.50
# Epoch    86, train loss 0.037464, train error 0.62,  val loss 0.390084, percent error 8.50
# Epoch    87, train loss 0.037383, train error 0.65,  val loss 0.389067, percent error 8.60
# Epoch    88, train loss 0.037438, train error 0.62,  val loss 0.394239, percent error 8.60
# Epoch    89, train loss 0.036758, train error 0.62,  val loss 0.388017, percent error 8.50
# Epoch    90, train loss 0.036734, train error 0.62,  val loss 0.388320, percent error 8.50
# Epoch    91, train loss 0.037556, train error 0.60,  val loss 0.393935, percent error 8.70
# Epoch    92, train loss 0.036784, train error 0.55,  val loss 0.392644, percent error 8.50
# Epoch    93, train loss 0.036422, train error 0.57,  val loss 0.391711, percent error 8.70
# Epoch    94, train loss 0.035954, train error 0.60,  val loss 0.392522, percent error 8.60
# Epoch    95, train loss 0.036452, train error 0.55,  val loss 0.394431, percent error 8.60
# Epoch    96, train loss 0.035617, train error 0.60,  val loss 0.393022, percent error 8.80
# Epoch    97, train loss 0.035543, train error 0.62,  val loss 0.396616, percent error 8.80
# Epoch    98, train loss 0.035464, train error 0.57,  val loss 0.391910, percent error 8.30
# Epoch    99, train loss 0.035717, train error 0.62,  val loss 0.398956, percent error 8.70
