# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-fghl_pss
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-fghl_pss
#   fatal: unable to access 'https://github.com/greydanus/mnist1d/': Failed to connect to github.com port 443: Connection timed out
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-fghl_pss did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-fghl_pss did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i,D_k),torch.nn.ReLU(),torch.nn.Linear(D_k,D_k),torch.nn.ReLU(),torch.nn.Linear(D_k,D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in,nn.Linear):
      torch.nn.init.kaiming_normal_(layer_in.weight)
      layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.599111, train error 61.88,  test loss 1.670936, test error 67.20
# Epoch     1, train loss 1.367478, train error 51.67,  test loss 1.482934, test error 60.90
# Epoch     2, train loss 1.154119, train error 40.53,  test loss 1.326744, test error 52.40
# Epoch     3, train loss 1.018551, train error 35.78,  test loss 1.226430, test error 47.50
# Epoch     4, train loss 0.877866, train error 29.75,  test loss 1.158475, test error 45.20
# Epoch     5, train loss 0.789699, train error 27.50,  test loss 1.133482, test error 43.50
# Epoch     6, train loss 0.735702, train error 26.38,  test loss 1.153606, test error 43.20
# Epoch     7, train loss 0.659837, train error 22.93,  test loss 1.101009, test error 41.30
# Epoch     8, train loss 0.564695, train error 19.10,  test loss 1.071853, test error 40.30
# Epoch     9, train loss 0.509091, train error 16.18,  test loss 1.061821, test error 38.70
# Epoch    10, train loss 0.404848, train error 11.80,  test loss 1.016348, test error 38.30
# Epoch    11, train loss 0.368635, train error 10.50,  test loss 1.054518, test error 39.10
# Epoch    12, train loss 0.335116, train error 8.88,  test loss 1.017540, test error 37.60
# Epoch    13, train loss 0.312186, train error 7.88,  test loss 1.033016, test error 37.40
# Epoch    14, train loss 0.283523, train error 6.97,  test loss 1.046135, test error 37.10
# Epoch    15, train loss 0.252089, train error 5.18,  test loss 1.059901, test error 37.10
# Epoch    16, train loss 0.230613, train error 5.03,  test loss 1.096228, test error 36.60
# Epoch    17, train loss 0.209486, train error 3.85,  test loss 1.120010, test error 37.70
# Epoch    18, train loss 0.189535, train error 3.00,  test loss 1.123612, test error 37.00
# Epoch    19, train loss 0.179027, train error 3.28,  test loss 1.130980, test error 36.70
# Epoch    20, train loss 0.153348, train error 1.78,  test loss 1.128435, test error 36.20
# Epoch    21, train loss 0.141132, train error 1.43,  test loss 1.150062, test error 36.90
# Epoch    22, train loss 0.136935, train error 1.38,  test loss 1.157688, test error 36.90
# Epoch    23, train loss 0.126523, train error 0.95,  test loss 1.165154, test error 36.70
# Epoch    24, train loss 0.121071, train error 0.78,  test loss 1.177475, test error 36.80
# Epoch    25, train loss 0.116265, train error 0.70,  test loss 1.203672, test error 36.50
# Epoch    26, train loss 0.108811, train error 0.50,  test loss 1.214871, test error 37.00
# Epoch    27, train loss 0.107363, train error 0.70,  test loss 1.199242, test error 37.00
# Epoch    28, train loss 0.098868, train error 0.38,  test loss 1.230722, test error 36.90
# Epoch    29, train loss 0.096938, train error 0.43,  test loss 1.238915, test error 37.50
# Epoch    30, train loss 0.089693, train error 0.30,  test loss 1.242452, test error 36.50
# Epoch    31, train loss 0.086972, train error 0.18,  test loss 1.244662, test error 36.30
# Epoch    32, train loss 0.084656, train error 0.18,  test loss 1.252602, test error 36.10
# Epoch    33, train loss 0.083174, train error 0.18,  test loss 1.258511, test error 36.70
# Epoch    34, train loss 0.080785, train error 0.18,  test loss 1.263627, test error 36.40
# Epoch    35, train loss 0.079533, train error 0.18,  test loss 1.268038, test error 36.90
# Epoch    36, train loss 0.077567, train error 0.18,  test loss 1.275565, test error 36.10
# Epoch    37, train loss 0.075724, train error 0.18,  test loss 1.276791, test error 36.70
# Epoch    38, train loss 0.074017, train error 0.15,  test loss 1.280491, test error 36.90
# Epoch    39, train loss 0.072879, train error 0.15,  test loss 1.291685, test error 37.00
# Epoch    40, train loss 0.071086, train error 0.15,  test loss 1.289174, test error 35.90
# Epoch    41, train loss 0.070328, train error 0.18,  test loss 1.296821, test error 36.80
# Epoch    42, train loss 0.069514, train error 0.15,  test loss 1.294473, test error 36.40
# Epoch    43, train loss 0.068757, train error 0.12,  test loss 1.296557, test error 36.40
# Epoch    44, train loss 0.068052, train error 0.10,  test loss 1.302619, test error 36.40
# Epoch    45, train loss 0.067259, train error 0.12,  test loss 1.304404, test error 36.60
# Epoch    46, train loss 0.066595, train error 0.15,  test loss 1.305721, test error 36.60
# Epoch    47, train loss 0.065870, train error 0.10,  test loss 1.310158, test error 36.30
# Epoch    48, train loss 0.065307, train error 0.12,  test loss 1.312414, test error 36.30
# Epoch    49, train loss 0.064595, train error 0.10,  test loss 1.315643, test error 36.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
