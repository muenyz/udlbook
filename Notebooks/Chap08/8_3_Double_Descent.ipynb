# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch, device):
  model.to(device)
  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)

  x_train = torch.tensor(data['x'].astype('float32')).to(device)
  y_train = torch.tensor(data['y'].transpose().astype('long')).to(device)
  x_test= torch.tensor(data['x_test'].astype('float32')).to(device)
  y_test = torch.tensor(data['y_test'].astype('long')).to(device)

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]).to(DEVICE) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch, DEVICE)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.250594, train error 86.85,  test loss 2.229167, test error 85.93
# Epoch   100, train loss 1.856777, train error 69.05,  test loss 1.685574, test error 66.77
# Epoch   200, train loss 1.847517, train error 70.62,  test loss 1.685415, test error 68.27
# Epoch   300, train loss 1.849016, train error 71.22,  test loss 1.685924, test error 68.25
# Epoch   400, train loss 1.840771, train error 69.97,  test loss 1.672082, test error 66.75
# Epoch   500, train loss 1.834561, train error 70.18,  test loss 1.674591, test error 66.52
# Epoch   600, train loss 1.839777, train error 70.82,  test loss 1.665724, test error 67.07
# Epoch   700, train loss 1.832692, train error 69.18,  test loss 1.676922, test error 67.05
# Epoch   800, train loss 1.833638, train error 69.27,  test loss 1.662696, test error 66.97
# Epoch   900, train loss 1.832007, train error 69.35,  test loss 1.659223, test error 66.75
# Training model with   4 hidden variables
# Epoch     0, train loss 2.246270, train error 83.07,  test loss 2.225978, test error 80.97
# Epoch   100, train loss 1.789792, train error 66.50,  test loss 1.613012, test error 63.65
# Epoch   200, train loss 1.771991, train error 64.82,  test loss 1.609762, test error 62.32
# Epoch   300, train loss 1.764629, train error 64.97,  test loss 1.612963, test error 63.12
# Epoch   400, train loss 1.762568, train error 64.77,  test loss 1.604147, test error 63.50
# Epoch   500, train loss 1.757781, train error 65.05,  test loss 1.595170, test error 61.90
# Epoch   600, train loss 1.738827, train error 63.15,  test loss 1.558326, test error 61.20
# Epoch   700, train loss 1.741980, train error 63.27,  test loss 1.565385, test error 62.12
# Epoch   800, train loss 1.717697, train error 62.32,  test loss 1.509278, test error 59.82
# Epoch   900, train loss 1.708950, train error 62.38,  test loss 1.505000, test error 58.65
# Training model with   6 hidden variables
# Epoch     0, train loss 2.284447, train error 85.00,  test loss 2.275317, test error 84.12
# Epoch   100, train loss 1.663264, train error 58.75,  test loss 1.501565, test error 58.62
# Epoch   200, train loss 1.622575, train error 58.35,  test loss 1.463705, test error 56.37
# Epoch   300, train loss 1.602512, train error 57.15,  test loss 1.465791, test error 56.82
# Epoch   400, train loss 1.597049, train error 56.70,  test loss 1.457859, test error 57.12
# Epoch   500, train loss 1.601751, train error 56.97,  test loss 1.457809, test error 56.75
# Epoch   600, train loss 1.594736, train error 56.67,  test loss 1.454224, test error 56.57
# Epoch   700, train loss 1.601656, train error 56.80,  test loss 1.470780, test error 57.02
# Epoch   800, train loss 1.597644, train error 56.90,  test loss 1.473963, test error 57.05
# Epoch   900, train loss 1.588883, train error 56.50,  test loss 1.461329, test error 56.72
# Training model with   8 hidden variables
# Epoch     0, train loss 2.244447, train error 83.70,  test loss 2.226221, test error 82.25
# Epoch   100, train loss 1.534359, train error 53.10,  test loss 1.362876, test error 50.57
# Epoch   200, train loss 1.499127, train error 51.92,  test loss 1.345903, test error 48.82
# Epoch   300, train loss 1.483204, train error 52.12,  test loss 1.357139, test error 49.67
# Epoch   400, train loss 1.478256, train error 51.75,  test loss 1.354678, test error 49.82
# Epoch   500, train loss 1.477761, train error 51.85,  test loss 1.359222, test error 50.32
# Epoch   600, train loss 1.475965, train error 52.40,  test loss 1.365280, test error 51.17
# Epoch   700, train loss 1.470680, train error 52.40,  test loss 1.368600, test error 50.80
# Epoch   800, train loss 1.469180, train error 51.82,  test loss 1.359649, test error 50.90
# Epoch   900, train loss 1.465245, train error 51.62,  test loss 1.361348, test error 50.62
# Training model with  10 hidden variables
# Epoch     0, train loss 2.218938, train error 81.93,  test loss 2.189682, test error 81.35
# Epoch   100, train loss 1.555061, train error 54.22,  test loss 1.437264, test error 55.55
# Epoch   200, train loss 1.487576, train error 50.95,  test loss 1.387438, test error 52.25
# Epoch   300, train loss 1.463977, train error 49.82,  test loss 1.385598, test error 52.47
# Epoch   400, train loss 1.452231, train error 49.37,  test loss 1.383299, test error 52.20
# Epoch   500, train loss 1.439407, train error 49.15,  test loss 1.383482, test error 50.55
# Epoch   600, train loss 1.431875, train error 48.32,  test loss 1.385264, test error 50.90
# Epoch   700, train loss 1.428774, train error 48.97,  test loss 1.373438, test error 50.02
# Epoch   800, train loss 1.417770, train error 48.45,  test loss 1.378275, test error 50.05
# Epoch   900, train loss 1.418311, train error 48.80,  test loss 1.397007, test error 50.97
# Training model with  14 hidden variables
# Epoch     0, train loss 2.280923, train error 86.50,  test loss 2.279007, test error 87.28
# Epoch   100, train loss 1.482238, train error 51.32,  test loss 1.389145, test error 53.40
# Epoch   200, train loss 1.388006, train error 46.55,  test loss 1.335846, test error 49.50
# Epoch   300, train loss 1.354950, train error 45.42,  test loss 1.346071, test error 49.65
# Epoch   400, train loss 1.328270, train error 44.82,  test loss 1.357146, test error 49.45
# Epoch   500, train loss 1.310719, train error 44.27,  test loss 1.360342, test error 49.12
# Epoch   600, train loss 1.296560, train error 43.75,  test loss 1.387659, test error 49.62
# Epoch   700, train loss 1.293833, train error 44.32,  test loss 1.385377, test error 49.72
# Epoch   800, train loss 1.273890, train error 43.25,  test loss 1.395488, test error 50.22
# Epoch   900, train loss 1.267882, train error 42.90,  test loss 1.433785, test error 51.20
# Training model with  18 hidden variables
# Epoch     0, train loss 2.218608, train error 81.57,  test loss 2.202577, test error 81.15
# Epoch   100, train loss 1.363726, train error 45.80,  test loss 1.375779, test error 51.97
# Epoch   200, train loss 1.269772, train error 42.70,  test loss 1.361077, test error 50.37
# Epoch   300, train loss 1.218271, train error 41.05,  test loss 1.382360, test error 49.97
# Epoch   400, train loss 1.186753, train error 39.85,  test loss 1.400359, test error 50.12
# Epoch   500, train loss 1.172615, train error 39.07,  test loss 1.443468, test error 50.52
# Epoch   600, train loss 1.169060, train error 38.77,  test loss 1.479817, test error 51.12
# Epoch   700, train loss 1.152838, train error 38.37,  test loss 1.509278, test error 51.90
# Epoch   800, train loss 1.159840, train error 39.32,  test loss 1.530998, test error 51.82
# Epoch   900, train loss 1.136793, train error 38.30,  test loss 1.550744, test error 52.17
# Training model with  22 hidden variables
# Epoch     0, train loss 2.215701, train error 81.25,  test loss 2.192621, test error 80.32
# Epoch   100, train loss 1.263513, train error 42.27,  test loss 1.304799, test error 48.25
# Epoch   200, train loss 1.141173, train error 38.07,  test loss 1.383580, test error 49.25
# Epoch   300, train loss 1.069387, train error 35.75,  test loss 1.446394, test error 49.75
# Epoch   400, train loss 1.051594, train error 35.75,  test loss 1.516135, test error 50.15
# Epoch   500, train loss 1.016097, train error 34.15,  test loss 1.557198, test error 51.87
# Epoch   600, train loss 1.009407, train error 34.60,  test loss 1.629293, test error 52.15
# Epoch   700, train loss 0.991500, train error 33.57,  test loss 1.638495, test error 51.45
# Epoch   800, train loss 0.986634, train error 33.40,  test loss 1.671896, test error 51.72
# Epoch   900, train loss 0.976529, train error 33.00,  test loss 1.678019, test error 51.90
# Training model with  26 hidden variables
# Epoch     0, train loss 2.111569, train error 78.75,  test loss 2.053415, test error 78.00
# Epoch   100, train loss 1.192677, train error 38.52,  test loss 1.289407, test error 46.52
# Epoch   200, train loss 1.022858, train error 33.82,  test loss 1.399989, test error 48.77
# Epoch   300, train loss 0.942141, train error 30.27,  test loss 1.531982, test error 50.10
# Epoch   400, train loss 0.898370, train error 28.38,  test loss 1.650187, test error 51.10
# Epoch   500, train loss 0.861495, train error 27.60,  test loss 1.732743, test error 51.25
# Epoch   600, train loss 0.837289, train error 27.22,  test loss 1.862841, test error 52.82
# Epoch   700, train loss 0.820021, train error 26.88,  test loss 1.936423, test error 53.00
# Epoch   800, train loss 0.804967, train error 26.50,  test loss 2.002616, test error 53.20
# Epoch   900, train loss 0.794581, train error 26.25,  test loss 2.057615, test error 52.92
# Training model with  30 hidden variables
# Epoch     0, train loss 2.187794, train error 80.40,  test loss 2.155575, test error 79.93
# Epoch   100, train loss 1.103615, train error 36.05,  test loss 1.313347, test error 47.97
# Epoch   200, train loss 0.923002, train error 31.02,  test loss 1.509222, test error 50.22
# Epoch   300, train loss 0.836675, train error 28.00,  test loss 1.713265, test error 51.47
# Epoch   400, train loss 0.788738, train error 27.55,  test loss 1.914341, test error 53.40
# Epoch   500, train loss 0.746044, train error 25.80,  test loss 2.048895, test error 52.47
# Epoch   600, train loss 0.724925, train error 24.90,  test loss 2.217985, test error 53.52
# Epoch   700, train loss 0.692859, train error 24.05,  test loss 2.376860, test error 54.22
# Epoch   800, train loss 0.681829, train error 23.80,  test loss 2.447866, test error 54.00
# Epoch   900, train loss 0.665434, train error 23.17,  test loss 2.576651, test error 54.52
# Training model with  35 hidden variables
# Epoch     0, train loss 2.172224, train error 81.10,  test loss 2.137999, test error 80.15
# Epoch   100, train loss 1.000252, train error 33.42,  test loss 1.383971, test error 49.15
# Epoch   200, train loss 0.780991, train error 25.52,  test loss 1.686983, test error 51.70
# Epoch   300, train loss 0.669626, train error 21.17,  test loss 2.044036, test error 54.60
# Epoch   400, train loss 0.623647, train error 20.77,  test loss 2.329283, test error 54.70
# Epoch   500, train loss 0.581007, train error 19.32,  test loss 2.618881, test error 54.65
# Epoch   600, train loss 0.537921, train error 17.67,  test loss 2.827017, test error 55.50
# Epoch   700, train loss 0.524732, train error 17.07,  test loss 3.133900, test error 56.97
# Epoch   800, train loss 0.501665, train error 17.30,  test loss 3.323372, test error 55.90
# Epoch   900, train loss 0.473644, train error 16.12,  test loss 3.610524, test error 56.45
# Training model with  40 hidden variables
# Epoch     0, train loss 2.133571, train error 79.62,  test loss 2.095382, test error 79.03
# Epoch   100, train loss 0.951589, train error 31.05,  test loss 1.519349, test error 51.80
# Epoch   200, train loss 0.675925, train error 22.00,  test loss 1.913248, test error 52.00
# Epoch   300, train loss 0.518093, train error 16.37,  test loss 2.454729, test error 53.50
# Epoch   400, train loss 0.423864, train error 13.65,  test loss 2.926783, test error 54.40
# Epoch   500, train loss 0.399592, train error 13.32,  test loss 3.568078, test error 55.20
# Epoch   600, train loss 0.367563, train error 13.15,  test loss 4.097321, test error 55.87
# Epoch   700, train loss 0.301897, train error 10.50,  test loss 4.568115, test error 55.70
# Epoch   800, train loss 0.262197, train error 8.45,  test loss 4.893165, test error 55.42
# Epoch   900, train loss 0.281790, train error 10.17,  test loss 5.562201, test error 56.30
# Training model with  45 hidden variables
# Epoch     0, train loss 2.131513, train error 77.90,  test loss 2.099810, test error 78.90
# Epoch   100, train loss 0.871589, train error 27.92,  test loss 1.554766, test error 50.92
# Epoch   200, train loss 0.518277, train error 15.72,  test loss 2.199716, test error 53.70
# Epoch   300, train loss 0.324764, train error 10.00,  test loss 3.258030, test error 55.20
# Epoch   400, train loss 0.241175, train error 7.85,  test loss 4.432888, test error 55.87
# Epoch   500, train loss 0.170942, train error 5.15,  test loss 5.707809, test error 56.65
# Epoch   600, train loss 0.225037, train error 8.12,  test loss 6.976357, test error 57.50
# Epoch   700, train loss 0.020546, train error 0.02,  test loss 8.075904, test error 56.30
# Epoch   800, train loss 0.012299, train error -0.00,  test loss 8.984229, test error 56.60
# Epoch   900, train loss 0.008533, train error -0.00,  test loss 9.652998, test error 56.62
# Training model with  50 hidden variables
# Epoch     0, train loss 2.063740, train error 76.35,  test loss 2.024719, test error 77.80
# Epoch   100, train loss 0.711518, train error 21.62,  test loss 1.566007, test error 50.25
# Epoch   200, train loss 0.354494, train error 10.40,  test loss 2.677490, test error 53.75
# Epoch   300, train loss 0.173313, train error 4.97,  test loss 4.214619, test error 55.00
# Epoch   400, train loss 0.031459, train error -0.00,  test loss 5.832871, test error 56.22
# Epoch   500, train loss 0.013526, train error -0.00,  test loss 6.830328, test error 56.72
# Epoch   600, train loss 0.008468, train error -0.00,  test loss 7.500911, test error 56.87
# Epoch   700, train loss 0.006010, train error -0.00,  test loss 7.990052, test error 56.82
# Epoch   800, train loss 0.004640, train error -0.00,  test loss 8.374994, test error 56.87
# Epoch   900, train loss 0.003707, train error -0.00,  test loss 8.702763, test error 57.10
# Training model with  55 hidden variables
# Epoch     0, train loss 2.073544, train error 76.30,  test loss 2.027672, test error 76.15
# Epoch   100, train loss 0.593958, train error 18.35,  test loss 1.693351, test error 50.80
# Epoch   200, train loss 0.203838, train error 5.07,  test loss 3.098245, test error 52.72
# Epoch   300, train loss 0.033389, train error -0.00,  test loss 4.819004, test error 54.85
# Epoch   400, train loss 0.013269, train error -0.00,  test loss 5.793012, test error 54.32
# Epoch   500, train loss 0.007899, train error -0.00,  test loss 6.403193, test error 54.65
# Epoch   600, train loss 0.005504, train error -0.00,  test loss 6.826482, test error 54.75
# Epoch   700, train loss 0.004133, train error -0.00,  test loss 7.171472, test error 54.80
# Epoch   800, train loss 0.003279, train error -0.00,  test loss 7.452113, test error 54.97
# Epoch   900, train loss 0.002698, train error -0.00,  test loss 7.689039, test error 55.07
# Training model with  60 hidden variables
# Epoch     0, train loss 2.030804, train error 75.50,  test loss 2.009498, test error 76.20
# Epoch   100, train loss 0.519130, train error 15.65,  test loss 1.766024, test error 50.07
# Epoch   200, train loss 0.104448, train error 1.07,  test loss 3.383488, test error 53.50
# Epoch   300, train loss 0.020578, train error -0.00,  test loss 4.692259, test error 53.17
# Epoch   400, train loss 0.009634, train error -0.00,  test loss 5.384663, test error 53.47
# Epoch   500, train loss 0.006039, train error -0.00,  test loss 5.833847, test error 53.62
# Epoch   600, train loss 0.004361, train error -0.00,  test loss 6.163780, test error 53.75
# Epoch   700, train loss 0.003323, train error -0.00,  test loss 6.435209, test error 53.60
# Epoch   800, train loss 0.002668, train error -0.00,  test loss 6.651760, test error 53.87
# Epoch   900, train loss 0.002212, train error -0.00,  test loss 6.840059, test error 53.85
# Training model with  70 hidden variables
# Epoch     0, train loss 2.048275, train error 76.65,  test loss 1.990422, test error 75.60
# Epoch   100, train loss 0.389950, train error 10.02,  test loss 1.995476, test error 52.62
# Epoch   200, train loss 0.035674, train error -0.00,  test loss 3.590283, test error 53.70
# Epoch   300, train loss 0.011337, train error -0.00,  test loss 4.393750, test error 54.25
# Epoch   400, train loss 0.006280, train error -0.00,  test loss 4.848098, test error 54.25
# Epoch   500, train loss 0.004221, train error -0.00,  test loss 5.156925, test error 54.50
# Epoch   600, train loss 0.003115, train error -0.00,  test loss 5.394436, test error 54.47
# Epoch   700, train loss 0.002442, train error -0.00,  test loss 5.583197, test error 54.45
# Epoch   800, train loss 0.001995, train error -0.00,  test loss 5.748665, test error 54.60
# Epoch   900, train loss 0.001671, train error -0.00,  test loss 5.881656, test error 54.80
# Training model with  80 hidden variables
# Epoch     0, train loss 2.031224, train error 75.28,  test loss 1.977628, test error 75.15
# Epoch   100, train loss 0.230512, train error 4.02,  test loss 2.084401, test error 52.77
# Epoch   200, train loss 0.019393, train error -0.00,  test loss 3.424212, test error 52.90
# Epoch   300, train loss 0.007867, train error -0.00,  test loss 3.994508, test error 53.10
# Epoch   400, train loss 0.004667, train error -0.00,  test loss 4.328215, test error 53.30
# Epoch   500, train loss 0.003239, train error -0.00,  test loss 4.565215, test error 53.35
# Epoch   600, train loss 0.002440, train error -0.00,  test loss 4.749225, test error 53.50
# Epoch   700, train loss 0.001941, train error -0.00,  test loss 4.897536, test error 53.45
# Epoch   800, train loss 0.001598, train error -0.00,  test loss 5.022560, test error 53.40
# Epoch   900, train loss 0.001351, train error -0.00,  test loss 5.131950, test error 53.52
# Training model with  90 hidden variables
# Epoch     0, train loss 1.982324, train error 74.55,  test loss 1.906695, test error 73.45
# Epoch   100, train loss 0.128921, train error 0.67,  test loss 2.198091, test error 50.80
# Epoch   200, train loss 0.014240, train error -0.00,  test loss 3.228315, test error 51.00
# Epoch   300, train loss 0.006336, train error -0.00,  test loss 3.648937, test error 51.00
# Epoch   400, train loss 0.003898, train error -0.00,  test loss 3.910945, test error 50.95
# Epoch   500, train loss 0.002742, train error -0.00,  test loss 4.100107, test error 51.05
# Epoch   600, train loss 0.002085, train error -0.00,  test loss 4.248668, test error 51.22
# Epoch   700, train loss 0.001670, train error -0.00,  test loss 4.370769, test error 51.10
# Epoch   800, train loss 0.001383, train error -0.00,  test loss 4.473022, test error 51.27
# Epoch   900, train loss 0.001175, train error -0.00,  test loss 4.562184, test error 51.35
# Training model with 100 hidden variables
# Epoch     0, train loss 2.003946, train error 73.95,  test loss 1.938308, test error 73.88
# Epoch   100, train loss 0.102766, train error 0.27,  test loss 2.172223, test error 49.82
# Epoch   200, train loss 0.012817, train error -0.00,  test loss 3.061567, test error 50.25
# Epoch   300, train loss 0.005869, train error -0.00,  test loss 3.432030, test error 50.30
# Epoch   400, train loss 0.003617, train error -0.00,  test loss 3.664441, test error 50.40
# Epoch   500, train loss 0.002561, train error -0.00,  test loss 3.832042, test error 50.47
# Epoch   600, train loss 0.001958, train error -0.00,  test loss 3.963031, test error 50.42
# Epoch   700, train loss 0.001570, train error -0.00,  test loss 4.071491, test error 50.37
# Epoch   800, train loss 0.001303, train error -0.00,  test loss 4.164043, test error 50.45
# Epoch   900, train loss 0.001109, train error -0.00,  test loss 4.243612, test error 50.55
# Training model with 120 hidden variables
# Epoch     0, train loss 1.951051, train error 72.15,  test loss 1.889062, test error 71.60
# Epoch   100, train loss 0.052775, train error -0.00,  test loss 2.246256, test error 50.52
# Epoch   200, train loss 0.009553, train error -0.00,  test loss 2.881653, test error 50.65
# Epoch   300, train loss 0.004711, train error -0.00,  test loss 3.171325, test error 50.55
# Epoch   400, train loss 0.003006, train error -0.00,  test loss 3.352364, test error 50.55
# Epoch   500, train loss 0.002166, train error -0.00,  test loss 3.485889, test error 50.57
# Epoch   600, train loss 0.001672, train error -0.00,  test loss 3.593610, test error 50.50
# Epoch   700, train loss 0.001351, train error -0.00,  test loss 3.681279, test error 50.40
# Epoch   800, train loss 0.001128, train error -0.00,  test loss 3.756169, test error 50.30
# Epoch   900, train loss 0.000964, train error -0.00,  test loss 3.821059, test error 50.27
# Training model with 140 hidden variables
# Epoch     0, train loss 1.954327, train error 72.40,  test loss 1.888041, test error 73.25
# Epoch   100, train loss 0.035276, train error -0.00,  test loss 2.145173, test error 50.25
# Epoch   200, train loss 0.008042, train error -0.00,  test loss 2.623685, test error 50.80
# Epoch   300, train loss 0.004145, train error -0.00,  test loss 2.848296, test error 50.55
# Epoch   400, train loss 0.002697, train error -0.00,  test loss 2.996492, test error 50.50
# Epoch   500, train loss 0.001962, train error -0.00,  test loss 3.108785, test error 50.45
# Epoch   600, train loss 0.001525, train error -0.00,  test loss 3.196200, test error 50.57
# Epoch   700, train loss 0.001239, train error -0.00,  test loss 3.269403, test error 50.52
# Epoch   800, train loss 0.001037, train error -0.00,  test loss 3.332801, test error 50.57
# Epoch   900, train loss 0.000888, train error -0.00,  test loss 3.386852, test error 50.60
# Training model with 160 hidden variables
# Epoch     0, train loss 1.949034, train error 71.72,  test loss 1.858422, test error 72.00
# Epoch   100, train loss 0.028602, train error -0.00,  test loss 2.070109, test error 48.12
# Epoch   200, train loss 0.007145, train error -0.00,  test loss 2.471588, test error 48.15
# Epoch   300, train loss 0.003744, train error -0.00,  test loss 2.668501, test error 48.20
# Epoch   400, train loss 0.002460, train error -0.00,  test loss 2.797405, test error 48.12
# Epoch   500, train loss 0.001797, train error -0.00,  test loss 2.895275, test error 48.22
# Epoch   600, train loss 0.001402, train error -0.00,  test loss 2.972790, test error 48.22
# Epoch   700, train loss 0.001142, train error -0.00,  test loss 3.037650, test error 48.17
# Epoch   800, train loss 0.000959, train error -0.00,  test loss 3.092508, test error 48.17
# Epoch   900, train loss 0.000823, train error -0.00,  test loss 3.140364, test error 48.07
# Training model with 180 hidden variables
# Epoch     0, train loss 1.951339, train error 71.32,  test loss 1.887807, test error 73.07
# Epoch   100, train loss 0.024224, train error -0.00,  test loss 2.066060, test error 48.65
# Epoch   200, train loss 0.006555, train error -0.00,  test loss 2.428892, test error 48.85
# Epoch   300, train loss 0.003511, train error -0.00,  test loss 2.608613, test error 49.02
# Epoch   400, train loss 0.002322, train error -0.00,  test loss 2.728506, test error 48.90
# Epoch   500, train loss 0.001710, train error -0.00,  test loss 2.819082, test error 49.02
# Epoch   600, train loss 0.001340, train error -0.00,  test loss 2.892066, test error 49.07
# Epoch   700, train loss 0.001094, train error -0.00,  test loss 2.952785, test error 49.00
# Epoch   800, train loss 0.000920, train error -0.00,  test loss 3.005879, test error 49.02
# Epoch   900, train loss 0.000791, train error -0.00,  test loss 3.051227, test error 49.02
# Training model with 200 hidden variables
# Epoch     0, train loss 1.932812, train error 70.45,  test loss 1.853278, test error 71.00
# Epoch   100, train loss 0.021385, train error -0.00,  test loss 1.932095, test error 47.70
# Epoch   200, train loss 0.006168, train error -0.00,  test loss 2.236913, test error 47.17
# Epoch   300, train loss 0.003351, train error -0.00,  test loss 2.395585, test error 47.10
# Epoch   400, train loss 0.002238, train error -0.00,  test loss 2.503458, test error 46.97
# Epoch   500, train loss 0.001654, train error -0.00,  test loss 2.584121, test error 47.00
# Epoch   600, train loss 0.001299, train error -0.00,  test loss 2.649588, test error 47.10
# Epoch   700, train loss 0.001063, train error -0.00,  test loss 2.703574, test error 47.10
# Epoch   800, train loss 0.000895, train error -0.00,  test loss 2.750312, test error 47.17
# Epoch   900, train loss 0.000770, train error -0.00,  test loss 2.790400, test error 47.27
# Training model with 250 hidden variables
# Epoch     0, train loss 1.901355, train error 68.60,  test loss 1.817269, test error 70.40
# Epoch   100, train loss 0.016932, train error -0.00,  test loss 1.940107, test error 47.27
# Epoch   200, train loss 0.005315, train error -0.00,  test loss 2.200262, test error 47.45
# Epoch   300, train loss 0.002962, train error -0.00,  test loss 2.337149, test error 47.32
# Epoch   400, train loss 0.002001, train error -0.00,  test loss 2.429824, test error 47.30
# Epoch   500, train loss 0.001489, train error -0.00,  test loss 2.500608, test error 47.25
# Epoch   600, train loss 0.001175, train error -0.00,  test loss 2.557177, test error 47.35
# Epoch   700, train loss 0.000965, train error -0.00,  test loss 2.605590, test error 47.35
# Epoch   800, train loss 0.000815, train error -0.00,  test loss 2.646502, test error 47.27
# Epoch   900, train loss 0.000703, train error -0.00,  test loss 2.683436, test error 47.37
# Training model with 300 hidden variables
# Epoch     0, train loss 1.875127, train error 67.45,  test loss 1.789361, test error 69.85
# Epoch   100, train loss 0.014505, train error -0.00,  test loss 1.829368, test error 46.75
# Epoch   200, train loss 0.004825, train error -0.00,  test loss 2.034450, test error 46.20
# Epoch   300, train loss 0.002735, train error -0.00,  test loss 2.148300, test error 46.32
# Epoch   400, train loss 0.001859, train error -0.00,  test loss 2.224762, test error 46.30
# Epoch   500, train loss 0.001391, train error -0.00,  test loss 2.283852, test error 46.15
# Epoch   600, train loss 0.001102, train error -0.00,  test loss 2.331470, test error 45.90
# Epoch   700, train loss 0.000907, train error -0.00,  test loss 2.371727, test error 45.90
# Epoch   800, train loss 0.000767, train error -0.00,  test loss 2.405986, test error 45.82
# Epoch   900, train loss 0.000663, train error -0.00,  test loss 2.435981, test error 45.82
# Training model with 400 hidden variables
# Epoch     0, train loss 1.829979, train error 65.70,  test loss 1.741202, test error 67.07
# Epoch   100, train loss 0.011470, train error -0.00,  test loss 1.775193, test error 45.45
# Epoch   200, train loss 0.004111, train error -0.00,  test loss 1.950620, test error 45.30
# Epoch   300, train loss 0.002384, train error -0.00,  test loss 2.047570, test error 45.07
# Epoch   400, train loss 0.001644, train error -0.00,  test loss 2.115813, test error 44.97
# Epoch   500, train loss 0.001239, train error -0.00,  test loss 2.167854, test error 45.07
# Epoch   600, train loss 0.000987, train error -0.00,  test loss 2.210594, test error 45.05
# Epoch   700, train loss 0.000816, train error -0.00,  test loss 2.246078, test error 45.07
# Epoch   800, train loss 0.000692, train error -0.00,  test loss 2.277165, test error 45.10
# Epoch   900, train loss 0.000600, train error -0.00,  test loss 2.304311, test error 45.07

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
